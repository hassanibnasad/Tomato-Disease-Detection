# %%
import sklearn 
import tensorflow as tf
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
     "Train",
     image_size=(256, 256),
     shuffle = True,
     batch_size=32
     )
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
     "Val",
     image_size=(256, 256),
     shuffle = True,
     batch_size=32
     )
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
     "Test",
     image_size=(256, 256),
     shuffle = True,
     batch_size=32
     )
# Out:
# Found 11108 files belonging to 6 classes.
# Found 2495 files belonging to 6 classes.
# Found 280 files belonging to 6 classes.

# %%
class_names=train_ds.class_names
class_names
# Out:
# ['Bacterial Spot',
#  'Early Blight',
#  'Healthy',
#  'Late Blight',
#  'Septoria Leaf Spot',
#  'Yellow Leaf Curl Virus']

# %%
iterator = train_ds.as_numpy_iterator()
# Get the first batch of images and labels
batch = next(iterator)

# Assuming the first element of the batch is the image
image = batch[0][0]
label = batch[1][0] # Get the label for the first image

plt.imshow(image.astype("uint8")) # Corrected the type to "uint8"
plt.title(class_names[label]) # Access class names from train_ds and use label index
# Out:
# Text(0.5, 1.0, 'Early Blight')

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras import models, layers
reshape_resize = tf.keras.Sequential([
    layers.Resizing(256,256),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),           # Randomly flip images horizontally
    layers.RandomRotation(0.1),                # Randomly rotate images by 10%
    layers.RandomZoom(0.1),                    # Randomly zoom images
    layers.RandomContrast(0.1),                # Adjust contrast slightly
   layers.RandomTranslation(0.1, 0.1),        # Random shift in width and height
    ])

# %%
base_model = tf.keras.applications.MobileNetV2(
      input_shape=(256, 256, 3),
      include_top=False,  # Remove final dense layers of MobileNetV2
      weights='imagenet'  # Load pretrained weights
      )
base_model.trainable = False  # Freeze the base model layers
# Out:
# C:\Users\LC\AppData\Local\Temp\ipykernel_4672\1966742154.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(

# %%
                                            # Build the complete model
model = models.Sequential([
    data_augmentation,
    reshape_resize,
    base_model,
    layers.GlobalAveragePooling2D(),         # Flattening
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(6, activation='softmax')  # Output lay
    ])
model.build()

# %%
'''model = models.Sequential([
    reshape_resize,
    data_augmentation,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(32,256,256,3)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(6,activation='softmax')
])
model.build(input_shape=(32,256,256,3))'''
# Out:
# "model = models.Sequential([\n    reshape_resize,\n    data_augmentation,\n    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(32,256,256,3)),\n    layers.MaxPooling2D((2,2)),\n    layers.Conv2D(64, kernel_size=(3,3),activation='relu'),\n    layers.MaxPooling2D((2,2)),\n    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),\n    layers.MaxPooling2D((2,2)),\n    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),\n    layers.MaxPooling2D((2,2)),\n    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),\n    layers.MaxPooling2D((2,2)),\n    layers.Flatten(),\n    layers.Dense(64,activation='relu'),\n    layers.Dense(6,activation='softmax')\n])\nmodel.build(input_shape=(32,256,256,3))"

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (32, 8, 8, 1280)       │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (32, 1280)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (32, 128)              │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (32, 128)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (32, 6)                │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,726 (9.24 MB)
#  Trainable params: 164,742 (643.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(train_ds, validation_data=val_ds, epochs=5,verbose=1,batch_size=32)
# Out:
# Epoch 1/5
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 274s 773ms/step - accuracy: 0.7141 - loss: 0.7636 - val_accuracy: 0.8721 - val_loss: 0.3529
# Epoch 2/5
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 277s 796ms/step - accuracy: 0.8743 - loss: 0.3346 - val_accuracy: 0.8874 - val_loss: 0.3148
# Epoch 3/5
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 272s 783ms/step - accuracy: 0.9117 - loss: 0.2537 - val_accuracy: 0.8946 - val_loss: 0.2946
# Epoch 4/5
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 273s 784ms/step - accuracy: 0.9144 - loss: 0.2379 - val_accuracy: 0.9206 - val_loss: 0.2145
# Epoch 5/5
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 274s 788ms/step - accuracy: 0.9249 - loss: 0.2118 - val_accuracy: 0.9190 - val_loss: 0.2175

# %%
model.evaluate(test_ds)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 571ms/step - accuracy: 0.8847 - loss: 0.2410
# [0.22354571521282196, 0.8964285850524902]

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 5, 'steps': 348}

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss =  history.history['loss']
val_loss =  history.history['val_loss']

# %%
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Septoria Leaf Spot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# predicted label: Septoria Leaf Spot

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
model_version=1
model.save(f'../models/{model_version}.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
